# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#!pip install seaborn pandas matplotlib num
#!conda install openpyxl

# %%
#data = pd.read_csv("Group5.csv",sep='\t',lineterminator='\r', engine='c', encoding='latin1',,encoding_errors='ignore')
#data= pd.read_csv("Group5_utf8.csv",sep=';')
#%config Completer.use_jedi = False
df = pd.read_excel('Group5.xlsx')

# %%
df.describe()
df.shape
# Out:
# (132, 3)

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(8,6))


x = sns.histplot(df, x='S1', bins=18, kde=True, stat='density', alpha=0.65, ax=ax)
#sns.kdeplot(df, x='S1',ax=ax, color='red')
#sns.kdeplot(data=df,x='S1')
plt.show()

# %%
sns.kdeplot(data=df,x='S1')
# Out:
# <Axes: xlabel='S1', ylabel='Density'>

# %%
sns.violinplot(data=df.iloc[0:20],x='S1',annot=True)
#sns.boxenplot(data=df['S1'])
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#sns.histplot(x=df['S1'],kde=True)
#plt.show()

# %%
stats = pd.DataFrame()
stats['Central_tendency'] = df.sum() / len(df)
stats['mean']=df.mean()
stats['Std_Dev']=df.std()
stats['Var']=df.var()
#print(stats['Var'])

# %%
print(stats)
df.describe()
#data.head()
df.keys()
# Out:
#     Central_tendency        mean    Std_Dev         Var
# S1        483.424242  483.424242  18.854655  355.498034
# S2        375.590909  375.590909  16.555230  274.075642
# S3        351.727273  351.727273  30.093770  905.634976
# Index(['S1', 'S2', 'S3'], dtype='object')

# %% [markdown]
# - Calculate Percentiles

# %%
percentiles = np.percentile(df["S1"],[5,25,50,75,95])

# %%
print(percentiles)
# Out:
# [456.   466.75 481.5  496.25 514.45]
